# %% [markdown]
# while döngüsü.
# belli bir koşul sağlanan kadar işlemleri yapmaya devam eden bir döngüdür.

# %%
i=1
while i<=10:
    print("i'nin değeri", i)
    i +=1
# Out:
# i'nin değeri 1
# i'nin değeri 2
# i'nin değeri 3
# i'nin değeri 4
# i'nin değeri 5
# i'nin değeri 6
# i'nin değeri 7
# i'nin değeri 8
# i'nin değeri 9
# i'nin değeri 10

# %%
i=1
while i<=10:
    print("Merhaba Python", "-", i, sep="")
    i +=1
# Out:
# Merhaba Python-1
# Merhaba Python-2
# Merhaba Python-3
# Merhaba Python-4
# Merhaba Python-5
# Merhaba Python-6
# Merhaba Python-7
# Merhaba Python-8
# Merhaba Python-9
# Merhaba Python-10

# %%
liste = [1,2,3,4,5,6]
a = 0
while (a<len(liste)):
    print("Listenin indexi:", a, liste[a])
    a +=1
# Out:
# Listenin indexi: 0 1
# Listenin indexi: 1 2
# Listenin indexi: 2 3
# Listenin indexi: 3 4
# Listenin indexi: 4 5
# Listenin indexi: 5 6

# %%
liste=["Ayşe", "Hüseyin", "Kürşat","Ali"]
a=0
while (a<len(liste)):
    print("Argem öğrencisi:", liste[a])
    a+=1
# Out:
# Argem öğrencisi: Ayşe
# Argem öğrencisi: Hüseyin
# Argem öğrencisi: Kürşat
# Argem öğrencisi: Ali

# %%
#uyarı... sonsuz döngü. çalıştırmayı tavsiye etmiyoruz
i=0
while i<20:
    print(i)
