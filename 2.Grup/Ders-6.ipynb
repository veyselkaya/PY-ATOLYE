# %%
print("""*****************
Bilgi Yarışması
********************
""")

puan = 0
isim = input("Sevgili yarışmacı adını yazar mısın?:")
soru1 = input("1.Dünya ile ay arası kaç km dir?: \nA)149000\nB)145000\nC)235000\nD)389000\n")

if soru1 == "D" or soru1 == "d":
    puan = puan +10
    print("Tebrikler doğru cevabı bidin, Puanın:" ,puan)
    
else:
    puan = puan
    print("Maalesef bilemedin, Puanın:", puan)
    
soru2 = input("2.Kedilerin kaç patisi vardır?: \nA)3\nB)4\nC)1\nD)5\n")

if soru2 == "B" or soru2 == "b":
    puan = puan +10
    print("Tebrikler doğru cevabı bidin, Puanın:" ,puan)
    
else:
    puan = puan
    print("Maalesef bilemedin, Puanın:", puan)
    
soru3 = input("3.Jupiter sistemimizdeki bütün gezegenlerin kaç katıdır(kütle): \nA)2\nB)10\nC)20\nD)7\n")

if soru3 == "A" or soru3 == "a":
    puan = puan +10
    print("Tebrikler doğru cevabı bidin, Puanın:" ,puan)
    
else:
    puan = puan
    print("Maalesef bilemedin, Puanın:", puan)
    
print("Yarışma bitti...",isim, "\nTebrikler\nPuanın:", puan)
# Out:
# *****************
# Bilgi Yarışması
# ********************
# Sevgili yarışmacı adını yazar mısın?: Bulut
# 1.Dünya ile ay arası kaç km dir?:
# A)149000
# B)145000
# C)235000
# D)389000
#  d
# Tebrikler doğru cevabı bidin, Puanın: 10
# 2.Kedilerin kaç ayağı vardır?:
# A)3
# B)4
# C)1
# D)5
#  b
# Tebrikler doğru cevabı bidin, Puanın: 20
# 3.Jupiter sistemimizdeki bütün gezegenlerin kaç katıdır(kütle):
# A)2
# B)10
# C)20
# D)7
#  a
# Tebrikler doğru cevabı bidin, Puanın: 30
# Yarışma bitti... Bulut
# Tebrikler
# Puanın: 30
