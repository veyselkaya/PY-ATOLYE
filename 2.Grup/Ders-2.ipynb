# %%
listeler

# %%
meyveler = ["elma", "muz", "kivi", "portakal", "mandalina"]
print(meyveler)
# Out:
# ['elma', 'muz', 'kivi', 'portakal', 'mandalina']

# %%
type(meyveler)
# Out:
# list

# %%
len(meyveler)
# Out:
# 5

# %%
meyveler[0]
# Out:
# 'elma'

# %%
meyveler[1]
# Out:
# 'muz'

# %%
meyveler[20]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-4fe20de78dcd> in <module>
# ----> 1 meyveler[20]
#
# IndexError: list index out of range

# %%
meyveler[-1]
# Out:
# 'mandalina'

# %%
meyveler[2] = "Hurma"

# %%
print(meyveler)
# Out:
# ['elma', 'muz', 'Hurma', 'portakal', 'mandalina']

# %%
meyveler[-0]
# Out:
# 'elma'

# %% [markdown]
# -0=0

# %%
isim = "Ayşe Reyyan"
lst = list(isim)
lst
# Out:
# ['A', 'y', 'ş', 'e', ' ', 'R', 'e', 'y', 'y', 'a', 'n']

# %%
len(lst)
# Out:
# 10

# %%
liste = [1,2,3, [1,2,3,[1,22,3]]]
len(liste)
# Out:
# 4

# %%
liste[-1]
# Out:
# [1, 2, 3, [1, 2, 3]]

# %%
liste[3]
# Out:
# [1, 2, 3, [1, 22, 3]]

# %%
liste[3][3][1]
# Out:
# 22

# %%
liste = [1,2,3,4,5,6,7,8,9]
liste
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
liste[:3]
# Out:
# [1, 2, 3]

# %%
liste[3:]
# Out:
# [4, 5, 6, 7, 8, 9]

# %%
liste[1:5]
# Out:
# [2, 3, 4, 5]

# %%
liste[::2]
# Out:
# [1, 3, 5, 7, 9]

# %%
liste[::-1]

# %% [markdown]
# liste metodları
# append metodu.... listeye yeni bir eleman ekler

# %%
liste2= [5,6,7,8,9,10,40]
liste2.append(54)
liste2
# Out:
# [5, 6, 7, 8, 9, 10, 40, 54]

# %%
liste2.append("Burak")

# %%
liste2
# Out:
# [5, 6, 7, 8, 9, 10, 40, 54, 'Burak']

# %%
liste2.append([78,67,89])

# %%
liste2
# Out:
# [5, 6, 7, 8, 9, 10, 40, 54, 'Burak', [78, 67, 89]]

# %%
pop metodu listedeki son elemanı siler

# %%
liste2.pop()
# Out:
# [78, 67, 89]

# %%
liste2
# Out:
# [5, 6, 7, 8, 9, 10, 40, 54, 'Burak']

# %%
liste2.pop(8)
# Out:
# 'Burak'

# %%
liste2
# Out:
# [5, 6, 7, 8, 9, 10, 40, 54]

# %%
liste2.pop(4)
# Out:
# 9

# %%
liste2
# Out:
# [5, 6, 7, 8, 10, 40, 54]

# %% [markdown]
# sort metodu....küçükten büyüğe sıralar

# %%
liste = [23,34,12,5,67,32,45,89,21,11]
liste.sort()
liste
# Out:
# [5, 11, 12, 21, 23, 32, 34, 45, 67, 89]

# %%
liste.sort(reverse = True)

# %%
liste
# Out:
# [89, 67, 45, 34, 32, 23, 21, 12, 11, 5]

# %%
liste[0]
# Out:
# 89
