# %%
skor=0
print("""************
Bilgi Yarışmasına Hoşgeldiniz
************""")
soru1=input("""1.Soru:'Süreyya'olarak da geçen ve yedi yıldızdan oluşan yıldız kümesinin diğer adı nedir?
A)Aldeberan B)Cassiopeia C)Ülker D)Regulus""")
if soru1=="C"or soru1=="c"or soru1=="Ülker":
    print("Tebrikler! 10 puan kazandınız.")
    skor+=10
else:
    print("Maalesef soruyu bilemediniz.")
soru2=input("""2.Soru:Türkiye Selçukluları en güçlü dönemlerini hangi sultan zamanında yaşamışlardır?
A)Alparslan B)Melikşah C)Alaeddin Keykubat D)Sultan Sencar""")
if soru2=="C"or soru2=="c"or soru2=="Alaeddin Keykubat":
    print("Tebrikler!10 puan kazandınız.")
    skor+=10
else:
    print("Maalesef soruyu bilemediniz.")
soru3=input("""3.Soru:Müslümanların ilk deniz zaferinin adı nedir?
A)Mute Savaşı B)Zat'üs Savari Savaşı C)Preveze Savaşı D)Yermük Savaşı""")
if soru3=="B"or soru3=="b"or soru3=="Zat'üs Savari Savaşı":
    print("Tebrikler! 10 puan kazandınız.")
    skor+=10
else:
    print("Maalesef soruyu bilemediniz.")
# Out:
# ************
# Bilgi Yarışmasına Hoşgeldiniz
# ************
# 1.Soru:'Süreyya'olarak da geçen ve yedi yıldızdan oluşan yıldız kümesinin diğer adı nedir?
# A)Aldeberan B)Cassiopeia C)Ülker D)Regulus c
# Tebrikler! 10 puan kazandınız.
# 2.Soru:Türkiye Selçukluları en güçlü dönemlerini hangi sultan zamanında yaşamışlardır?
# A)Alparslan B)Melikşah C)Alaeddin Keykubat D)Sultan Sencar a
# Maalesef soruyu bilemediniz.
# 3.Soru:Müslümanların ilk deniz zaferinin adı nedir?
# A)Mute Savaşı B)Zat'üs Savari Savaşı C)Preveze Savaşı D)Yermük Savaşı c
# Maalesef soruyu bilemediniz.

# %%
sorular = ["Bir yılda kaç ay var?(cevap 12)","Güneş sisteminde kaç gezegen vardır?(cevap 8)","10/2 kaç eder? (cevap 5)"]
cevaplar = [12,8,5]
soru_no = 0
puan = 0
while soru_no < len(sorular):
    print(str(soru_no + 1)+". soru\n"+sorular[soru_no])
    cevap = int(input("Cevap:\n"))
    if cevap == cevaplar[soru_no]:
        puan += 10
        print("Doğru cevap! Puanın: {}".format(puan))
    else:
        puan -= 10
        print("Yanlış cevap :( Puanın: {}".format(puan))
    soru_no += 1
# Out:
# 1. soru
# Bir yılda kaç ay var?(cevap 12)
# Cevap:
#  11
# Yanlış cevap :( Puanın: -10
# 2. soru
# Güneş sisteminde kaç gezegen vardır?(cevap 8)
# Cevap:
#  8
# Doğru cevap! Puanın: 0
# 3. soru
# 10/2 kaç eder? (cevap 5)
# Cevap:
#  5
# Doğru cevap! Puanın: 10
