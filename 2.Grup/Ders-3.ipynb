# %% [markdown]
# Mantıksal değerler ve karşılaştırma operatörleri

# %% [markdown]
# Boolean (Mantıksal değer) True ve False olabilir

# %%
a = True
type(a)
# Out:
# bool

# %%
b = False
type(b)
# Out:
# bool

# %%
bool(5)
# Out:
# True

# %%
bool(67)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
print(1>2)
# Out:
# False

# %% [markdown]
# Karşılaştırma operatörleri
#
# == iki deeğr birbirinie eşitse kullanılır
# != iki değer birbirine eşit değilse
# > büyüktür operatörü
# < küçüktür operatörü
# >=
# <=

# %%
print(2==2)
# Out:
# True

# %%
print(4==5)
# Out:
# False

# %%
print(2!=3)
# Out:
# True

# %%
print(2!=2)
# Out:
# False

# %%
print(5>4)
# Out:
# True

# %%
print(5<3)
# Out:
# False

# %%
print(6>=5)
# Out:
# True

# %%
print(6>=6)
# Out:
# True

# %%
print(6>=7)
# Out:
# False

# %%
"veysel" == "veysel"
# Out:
# True

# %%
"Veysel" == "veysel"
# Out:
# False

# %%
3>5
# Out:
# False

# %%
45<=67
# Out:
# True

# %% [markdown]
# Mantıksal bağlaçlar

# %% [markdown]
# and operatörü herpsi doğru ise True en az bir tanesi yanlış ise False dönderir..

# %%
1<2 and "Murat" == "Murat"
# Out:
# True

# %%
1<2 and "Murat" == "Murat" and 6>5
# Out:
# True

# %%
1>2 and "Murat" == "Murat" and 6>5
# Out:
# False

# %% [markdown]
# or operatörü en az bir tane doğru varsaa True dönderir

# %%
3 ==3 or "Veysel" == "veysel"
# Out:
# True

# %%
3 !=3 or "kedi" =="Kedi"
# Out:
# False

# %%
5>=4 or 67>78 or 6!=6
# Out:
# True

# %% [markdown]
# not operatörü true is false, false ise true dönderir

# %%
not 2 == 2
# Out:
# False

# %%
 3!=4
# Out:
# True

# %%
not 3!=4
# Out:
# False

# %%
not (2.14 > 3.49 or ( 2 != 2 and "Murat" == "Murat"))
# Out:
# True

# %%
2 != 2 and "Murat" == "Murat"
# Out:
# False

# %%
2.14 > 3.49
# Out:
# False

# %%
False or False
# Out:
# False

# %%
not(False)
# Out:
# True

# %%
"Araba" < "Zula" and ( "Bebek" < "Çoçuk" or (not 14 ))

# %%
"Araba"<"Zula"
# Out:
# True

# %%
"Kedi">"Araba"
# Out:
# True

# %%
"Araba">"Bebek"
# Out:
# False

# %%
"Ayam">"Azam"
# Out:
# False

# %%
"Araba" < "Zula" and ( "Bebek" < "Çoçuk" or (not 14 ))
# Out:
# True
