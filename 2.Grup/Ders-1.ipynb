# %% [markdown]
# print(), format,  type(), input(), float, int, string, liste

# %% [markdown]
# print() fonksiyonunun özellikleri

# %%
print("Merhaba", 20)
# Out:
# Merhaba 20

# %%
print(20.5)
# Out:
# 20.5

# %% [markdown]
# \n yeni satır

# %%
print("Merhaba\nNasılsın")
# Out:
# Merhaba
# Nasılsın

# %%
print("Ocak\tŞubat\t\t\tMart")
# Out:
# Ocak	Şubat			Mart

# %% [markdown]
# type() fonksiyonu: değerin veri türünü bize söyler

# %%
type(2)
# Out:
# int

# %%
type("Kürşat")
# Out:
# str

# %%
type("2")
# Out:
# str

# %%
type(4.7)
# Out:
# float

# %%
isim = "Veysel"
type(isim)
# Out:
# str

# %%
ad = "Kemal"
print(type(ad))
# Out:
# <class 'str'>

# %% [markdown]
# sep özelliği

# %%
print("Argem", "Python", "Atölyesi", sep="-")
# Out:
# Argem-Python-Atölyesi

# %%
print("Argem", "Python", "Atölyesi", sep="\n")
# Out:
# Argem
# Python
# Atölyesi

# %%
print(*"Python")
# Out:
# P y t h o n

# %%
print(*"Python", sep="")
# Out:
# P&y&t&h&o&n

# %%
#T.B.M.M
a="TBMM"
print(*a,sep=".")
# Out:
# T.B.M.M

# %%
a = "veysel kaya"
print(a.upper())
# Out:
# VEYSEL KAYA

# %%
b = "ZEYNEP AHSEN"
print(b.lower())
# Out:
# zeynep ahsen

# %%
ad = "veysel"
soyad = "kaya"
print(ad.capitalize(), soyad.upper())
# Out:
# Veysel KAYA

# %% [markdown]
# # kullanıcının adını ve soyadını alıp kaydeden bir program
# ad_soyad = input("Adınızı ve soyadınızı giriniz: ")
# print(ad_soyad.upper(), "Hoş geldin, kaydını tamamladık")

# %% [markdown]
# format özelliği

# %%
a = 5
b = 20
print("{}+{} 'nin toplamı {}'dır".format(a,b,a+b))
# Out:
# 5+20 'nin toplamı 25 dır

# %%
a = int(input("Birinci sayıyı gir:"))
b = int(input("İkinci sayıyı gir: "))
print("{}+{} 'nin toplamı {}'dır".format(a,b,a+b))
# Out:
# Birinci sayıyı gir: 3
# İkinci sayıyı gir:  4
# 3+4 'nin toplamı 7'dır

# %% [markdown]
# title özelliği

# %%
a = "türkiye cumhuriyeti"
print(a.title())
# Out:
# Türkiye Cumhuriyeti

# %%
kelime = "argem python atölyesi"
print(*kelime.title())
# Out:
# A r g e m   P y t h o n   A t ö l y e s i

# %% [markdown]
# len() fonksiyonu

# %%
a="Argem"
b = print(*a, sep="-" )
b
# Out:
# A-r-g-e-m
