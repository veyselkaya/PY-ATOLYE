# %%
#Pythonda Modül...(hazır kullanabileceğimiz fonksiyonların olduğu kütüphanaler gibi düşünebiliriz)

# %%
#Math

# %%
import math

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(x, /)
#         Return the ceiling of x as an Integral.
#
#         This is the smallest integer >= x.
#
#     copysign(x, y, /)
# ...

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.pow(3,4)
# Out:
# 81.0

# %%
math.pow(2,30)
# Out:
# 1073741824.0

# %%
math.sqrt(100)
# Out:
# 10.0

# %%
math.ceil(5.2)
# Out:
# 6

# %%
math.ceil(5.9)
# Out:
# 6

# %%
math.floor(5.9)
# Out:
# 5

# %%
math.floor(5.2)
# Out:
# 5

# %%
math.factorial(3)
# Out:
# 6

# %%
import random

# %%
help(random)
# Out:
# Help on module random:
#
# NAME
#     random - Random variable generators.
#
# MODULE REFERENCE
#     https://docs.python.org/3.7/library/random
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#         integers
#         --------
#                uniform within range
#
#         sequences
#         ---------
#                pick random element
#                pick random sample
#                pick weighted random sample
#                generate random permutation
#
#         distributions on the real line:
#         ------------------------------
#                uniform
#                triangular
#                normal (Gaussian)
#                lognormal
# ...

# %%
random.random()
# Out:
# 0.2280975765393185

# %%
for elaman in range(10):
  print("Rastgele sayılar: {:.3f}".format(random.random()))
# Out:
# Rastgele sayılar: 0.209
# Rastgele sayılar: 0.387
# Rastgele sayılar: 0.592
# Rastgele sayılar: 0.788
# Rastgele sayılar: 0.089
# Rastgele sayılar: 0.984
# Rastgele sayılar: 0.651
# Rastgele sayılar: 0.334
# Rastgele sayılar: 0.599
# Rastgele sayılar: 0.481

# %%
for eleman in range(10):
  print("Rastgele sayılar : {}".format(random.randint(0,100)))
# Out:
# Rastgele sayılar : 92
# Rastgele sayılar : 89
# Rastgele sayılar : 13
# Rastgele sayılar : 2
# Rastgele sayılar : 56
# Rastgele sayılar : 13
# Rastgele sayılar : 48
# Rastgele sayılar : 22
# Rastgele sayılar : 45
# Rastgele sayılar : 60

# %%
liste = ["Kürşat", "Mirza", "Azra","Batu", "Alparslan", "Büşra", "Egemen"]
print("Kura sonucu: {}".format(random.choice(liste)))
# Out:
# Kura sonucu: Egemen

# %%
def kura():
  liste = ["Kürşat", "Mirza", "Azra","Batu", "Alparslan", "Büşra", "Egemen", "Meryem", "Taner", "Yaman"]
  print("Kura sonucu: {}".format(random.choice(liste)))

# %%
kura()
# Out:
# Kura sonucu: Meryem

# %%
#sayı tahmini tutturan python uygulaması...
sayi = random.randint(1,100)
print(sayi)
# Out:
# 8

# %%
rand = random.randint(1,100)
sayac=0
while True:
  sayac+=1
  sayi=int(input("1 ile 100 arasında sayı girin (0 Çıkış):"))
  if sayi == 0:
    print("Oyunu iptal ettiniz")
    break
  elif sayi < rand:
      print("Daha yüksek bir sayı girin.")
      continue
  elif sayi > rand:
      print ("Daha düşük bir sayı girin.")
      continue
  else:
     print("Rastgele seçilen sayı {0}!".format(rand))
     print("Tahmin sayınız {0}".format(sayac))
# Out:
# 1 ile 100 arasında sayı girin (0 Çıkış):25
# Daha yüksek bir sayı girin.
# 1 ile 100 arasında sayı girin (0 Çıkış):50
# Daha düşük bir sayı girin.
# 1 ile 100 arasında sayı girin (0 Çıkış):35
# Daha yüksek bir sayı girin.
# 1 ile 100 arasında sayı girin (0 Çıkış):40
# Daha yüksek bir sayı girin.
# 1 ile 100 arasında sayı girin (0 Çıkış):44
# Daha yüksek bir sayı girin.
# 1 ile 100 arasında sayı girin (0 Çıkış):47
# Daha yüksek bir sayı girin.
# 1 ile 100 arasında sayı girin (0 Çıkış):48
# Rastgele seçilen sayı 48!
# Tahmin sayınız 7
# 1 ile 100 arasında sayı girin (0 Çıkış):0
# Oyunu iptal ettiniz
