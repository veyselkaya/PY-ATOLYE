# %% [markdown]
# Mantıksal değerler ve karşılaştırma operatörleri
# Mantıksal derler
# Boolean True ve False

# %% [markdown]
# Karşılaştırma operatörleri
# == ikideğer birbirine eşit ise kulanılır
# < küçüktür operatörü
# > büyüktür operatörü
# <= küçük eşitti
# >= büyük eşitti
# != eşit değildir

# %%
2<4
# Out:
# True

# %%
2>5
# Out:
# False

# %%
2==2
# Out:
# True

# %%
4>3.999999
# Out:
# True

# %%
"Veysel" == "Veysel"
# Out:
# True

# %%
"veysel" =="Veysel"
# Out:
# False

# %%
"Adam">"Elma"
# Out:
# False

# %%
"Elma">"Adam"
# Out:
# True

# %%
45>=45
# Out:
# True

# %%
45<=45
# Out:
# True

# %% [markdown]
# Mantıksal operatörler

# %% [markdown]
# and operatörleri(her iki ifade doğru ise True dönderir)

# %%
1<2 and 4>3
# Out:
# True

# %%
2==2 and 5>3.9
# Out:
# True

# %%
3>5 and 89<=89
# Out:
# False

# %% [markdown]
# or operatörü (ifadelerden sadece biri doğru ise true sonucunu verir)

# %%
4>3 or 3>4
# Out:
# True

# %%
67>65 or 3.9<2.99
# Out:
# True

# %%
4>5 or 6>7
# Out:
# False

# %% [markdown]
# not operatörü (true ise false, false ise true yapar)

# %%
4<5
# Out:
# True

# %%
not 4<5
# Out:
# False

# %% [markdown]
# operatörleri beraber kullanma

# %%
not (False)
# Out:
# True

# %%
not (3>5 or 5.6<5) and ( 6.9>=7 and 7.8>=6)
# Out:
# False

# %%
#(3.9!=4 and 6.8<8) or (8.6>=7 or 5.8<=9)

(True) or (True)
# Out:
# True

# %%
(3.9!=4 and 6.8<8) or (8.6>=7 or 5.8<=9)
# Out:
# True

# %%
#not (1.13 >3.14 or (2 !=2 and "Azra" == "Azra"))

not (False)
# Out:
# True

# %%
not (1.13 >3.14 or (2 !=2 and "Azra" == "Azra"))
# Out:
# True
