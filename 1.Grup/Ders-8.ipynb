# %% [markdown]
# Kaoşullu durumlar
#
# if-elif-else

# %%
python kodlarının çalışma mantığı: Python yukarıdan aşapıya satır satır çalışırı.

# %%
a=4
if a==4:
    print("Doğru")
# Out:
# Doğru

# %%
a=4
if a==3:
    print("Doğru")

# %%
a=4
if a==3:
    print("Doğru")
else:
    print("Yanlış")
# Out:
# Yanlış
