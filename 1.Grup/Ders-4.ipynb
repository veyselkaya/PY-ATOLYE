# %% [markdown]
# print fonksiyonu ve formatlama

# %%
print("Argem")
# Out:
# Argem

# %%
print(34)
# Out:
# 34

# %%
print(3.14)
# Out:
# 3.14

# %%
a = 3
b = 5
print(a+b)
print(a*b)
print(a/b)
print(a**b)
# Out:
# 8
# 15
# 0.6
# 243

# %%
a = 3
b = 5
toplam = a+b
print('Toplam: ', toplam)
# Out:
# Toplam:  8

# %% [markdown]
# \n yeni satır özelliği

# %%
print("Merhaba. Argem'e hoşgeldiniz")
# Out:
# Merhaba. Argem'e hoşgeldiniz

# %%
print("Merhaba.\nArgem'e hoşgeldiniz")
# Out:
# Merhaba.
# Argem'e hoşgeldiniz

# %% [markdown]
# \t tab özelliği

# %%
print("Merhaba Python")
# Out:
# Merhaba Python

# %%
print("Merhaba \tPython")
# Out:
# Merhaba 	Python

# %%
print("Ocak \tŞubat \tMart \t\t\tDersler")
# Out:
# Ocak 	Şubat 	Mart 			Dersler

# %% [markdown]
# type() fonksiyonu

# %%
a="Kürşat"

type(a)
print(a+a)
# Out:
# KürşatKürşat

# %%
b = 8
type(b)
# Out:
# int

# %%
c = 1.9
type(c)
# Out:
# float

# %%
isim = "Alp"
soyad = "Erol"
print(isim+"    "+soyad)
# Out:
# Alp    Erol

# %%
d = 89
type(d)
# Out:
# int

# %%
print(type(d))
# Out:
# <class 'int'>

# %% [markdown]
# sep parametresi

# %%
print("Argem","Python","Atölyesi", sep="---->")
# Out:
# Argem---->Python---->Atölyesi

# %%
print("Argem","Python","Atölyesi", sep="\n")
# Out:
# Argem
# Python
# Atölyesi

# %% [markdown]
# * parametresi

# %%
print(*"Azra")
# Out:
# A z r a

# %%
print(*"Azra", sep="-")
# Out:
# A-z-r-a

# %%
print(*"ARGEM", sep=".")
# Out:
# A.R.G.E.M

# %%
print("veysel kaya")
# Out:
# veysel kaya

# %%
isim = "veysel kaya"
print(isim.upper())
# Out:
# VEYSEL KAYA

# %%
isim = "VEYSEL KAYA"
print(isim.lower())
# Out:
# veysel kaya

# %%
isim = "veysel kaya"
print(isim.capitalize())
# Out:
# Veysel kaya

# %%
ad= "argem python atölyesi"
print(ad.title())
# Out:
# Argem Python Atölyesi

# %%
ad= "aRgem pyHon atÖlYesi"
print(ad.title())
# Out:
# Argem Pyhhon Atölyesi

# %% [markdown]
# Formatlama

# %%
a = 9
b = 3
print("{}+{} toplamı: {}".format(a,b,a+b))
# Out:
# 9+3 toplamı: 12

# %%
a = 3.45456777
print("{}".format(a))
# Out:
# 3.45456777

# %%
a = 89.675687965786758675647586
print(int(a))
# Out:
# 89

# %% [markdown]
# örnek kullanıcıdan adını, soyadını, yaşını alıp format fornkiyonu ve \n ile bir satırda ekrana yazdıralım

# %%
ad = input("Adını yaz: ")
soyad= input("Soyadını yaz: ")
yas = int(input("Yaşını gir"))
print("Adın: {} \nSoyadın: {} \nYaşın: {}".format(ad, soyad,yas))
# Out:
# Adını yaz:  vEysel
# Soyadını yaz:  KAya
# Yaşını gir 39
# Adın: vEysel
# Soyadın: KAya
# Yaşın: 39

# %%
ad = input("Adını yaz: ")
soyad = input("Soyadını yaz: ")
yas = int(input("Yaşını gir"))
print("Adın: {} \nSoyadın: {} \nYaşın: {}".format(ad.capitalize(), soyad.upper(),yas))
